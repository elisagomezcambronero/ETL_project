# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("data/df_limpio.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                          Song_Name  Genre_Gen  \
# 0           0                                               UGH!        NaN
# 1           1                                   Bigger Than Life        NaN
# 2           2                                         Time Flies        NaN
# 3           3                   HOT WIND BLOWS (feat. Lil Wayne)        NaN
# 4           4  Wonderful Christmastime - Edited Version / Rem...        NaN
#
#    Genre1  Genre2 Release_Date Song_Decade    Streams  \
# 0     NaN     NaN   2020-02-21       2020s  9,991,177
# 1     NaN     NaN   2020-03-06       2020s  9,974,143
# 2     NaN     NaN   2020-05-01       2020s  9,904,749
# 3     NaN     NaN   2021-06-25       2020s  9,889,197
# 4     NaN     NaN   1980-05-16       1980s  9,882,989
#
#   Week_Of_Highest_Charting Month_Highest_Charting Season_Highest_Charting  \
# 0               2020-02-21               February                  Winter
# ...

# %%
def 
sns.scatterplot(x='Year_Highest_Charting', y='Popularity', data=df)
plt.title('Relación entre energía de las canciones y estación más famosa')
plt.xlabel('Energía')
plt.ylabel('Estación')
# Out:
# Text(0, 0.5, 'Estación')

# %%
sns.heatmap(df_song.corr(),
            cmap = "YlGnBu", 
           annot = True);
